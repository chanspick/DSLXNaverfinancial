# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 719.0 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 11.3 MB/s eta 0:00:00
# ...

# %%
import openai
import os
API_KEY = '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'
os.environ["OPENAI_API_KEY"] = API_KEY
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
messages = []
while True:
    content = input('User: ')
    messages.append({'role' : 'user', 'content' : content})

    completion = openai.ChatCompletion.create(
        model = 'gpt-3.5-turbo',
        messages = messages
    )

    chat_response = completion.choices[0].message.content
    print(f'ChatGPT: {chat_response}')

    messages.append({'role' : 'assistant', 'content' : chat_response})
# Out:
# User:  ''' 이 문장을 SQL문으로 바꿔 줘 Extract the lines whose subscription period is more than a month and the payment amount is more than 50,000 won Table of subscription period : Delta type of subscription period : string column of subscription period: Sub_A Table of payment amount: Delta column of payment amount: Pay_A '''
# ChatGPT: SELECT *
# FROM Sub_A
# JOIN Pay_A
# ON Sub_A.subscription_period > '1 month'
# AND Pay_A.payment_amount > 50000;
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2e41644530d5> in <cell line: 2>()
#       1 messages = []
#       2 while True:
# ----> 3     content = input('User: ')
#       4     messages.append({'role' : 'user', 'content' : content})
#       5
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
content = '''
이 문장을 SQL문으로 바꿔 줘
Extract the lines whose subscription period is more than a month and the payment amount is more than 50,000 won
Table of subscription period : Delta
type of subscription period : string
column of subscription period: Sub_A
Table of payment amount: Delta
column of payment amount: Pay_A
'''
messages.append({'role' : 'user', 'content' : content})

completion = openai.ChatCompletion.create(
    model = 'gpt-3.5-turbo',
    messages = messages
)

chat_response = completion.choices[0].message.content
print(f'ChatGPT: {chat_response}')
# Out:
# ChatGPT: SELECT *
# FROM Delta.Sub_A
# INNER JOIN Delta.Pay_A
# ON Delta.Sub_A.subscription_period > '1 month'
# AND Delta.Pay_A.payment_amount > 50000;
